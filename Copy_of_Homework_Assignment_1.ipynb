# %% [markdown]
# <a href="https://colab.research.google.com/github/bharti0204/MBAI_Hackathon_Repository/blob/main/Copy_of_Homework_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 1: Promoting Evening Products to Drive Incremental Revenue at Instacart

# %% [markdown]
# Your team has been brought to work with the merchandising team at Instacart.  The problem: early evening hours have delivery / driver availability but the number of orders falls off in the evening hours.
# &nbsp;
# We need to determine which products are being sold in the evening 6PM+ (18-23 in order_hour_of_day) hours so that the team can create new promotions.  To avoid developing a list of niche products we'd like to restrict our analysis to products that are ordered at least 5000 times.
# &nbsp;
#
# The merchandising team has the option of sending out emails or featuring products to shoppers on site, which do you recommend will be more effective in meeting the goal.  Feel free to call out additional data that would be helpful in evaluating the opportunity.
# &nbsp;
# All the data you need is stored in the redshift database.  Please update the code in each code cell to build to the final list of products.
# &nbsp;
# In the last markdown cell, please discuss your key findings and what next steps and data should be gathered in order to determine how the team should proceed to evaluate the opportunity.
# &nbsp;
# Please limit your analysis to 250 words.

# %% [markdown]
# # Setting up the environment

# %%
#@title installs for sqlalchemy and sqlmagic
# !pip install sqlalchemy-redshift --quiet
# !pip install redshift_connector --quiet
# !pip install ipython-sql --quiet

# %%
#@title standard imports - we'll use in most EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

from datetime import datetime, timedelta
from dateutil.parser import parse
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
#@title setting up sql connection and sql magic, unique to this lab

import getpass
import sqlalchemy as sa
from sqlalchemy.engine.url import URL
from sqlalchemy import orm as sa_orm

connect_to_db = URL.create(
drivername='redshift+redshift_connector',     
host='mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com',     
port=5439,  
database='dev',  
username='ro_user',         #username should not be hard coded either
password=getpass.getpass()  #please don't put passwords into code
)

engine = sa.create_engine(connect_to_db)
# %reload_ext sql
# %sql $connect_to_db

# %% [markdown]
# # Determining evening products

# %% [markdown]
# ## Show the number of orders by hour of day

# %%
# %%sql
# select order_hour_of_day as hour_of_day,
# count(order_id) as no_of_order from orders
# group by order_hour_of_day
# order by order_hour_of_day
# Out:
#  * redshift+redshift_connector://ro_user:***@mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# [(0, 22758),
#  (1, 12398),
#  (2, 7539),
#  (3, 5474),
#  (4, 5527),
#  (5, 9569),
#  (6, 30529),
#  (7, 91868),
#  (8, 178201),
#  (9, 257812),
#  (10, 288418),
#  (11, 284728),
#  (12, 272841),
#  (13, 277999),
#  (14, 283042),
#  (15, 283639),
#  (16, 272553),
#  (17, 228795),
#  (18, 182912),
#  (19, 140569),
#  (20, 104292),
#  (21, 78109),
#  (22, 61468),
#  (23, 40043)]

# %% [markdown]
# ## Determine the number of products ordered by hour of day

# %%
# %%sql
# select o.order_hour_of_day, count(op.product_id) as no_of_product
# from orders o
# inner join order_products op on o.order_id = op.order_id
# group by o.order_hour_of_day
# order by o.order_hour_of_day
# limit 100
# Out:
#  * redshift+redshift_connector://ro_user:***@mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# [(0, 218948),
#  (1, 115786),
#  (2, 69434),
#  (3, 51321),
#  (4, 53283),
#  (5, 88062),
#  (6, 290795),
#  (7, 891937),
#  (8, 1719973),
#  (9, 2456713),
#  (10, 2764426),
#  (11, 2738582),
#  (12, 2620847),
#  (13, 2663292),
#  (14, 2691548),
#  (15, 2664533),
#  (16, 2537458),
#  (17, 2089465),
#  (18, 1637923),
#  (19, 1259401),
#  (20, 977038),
#  (21, 796370),
#  (22, 634734),
#  (23, 402620)]

# %% [markdown]
# ## Calculate the basket size (# products / # orders) by hour of day

# %%
# %%sql
# select o.order_hour_of_day,
# count(op.product_id)/count(distinct o.order_id) as basket_size
# from orders o
# inner join order_products op on o.order_id = op.order_id
# group by o.order_hour_of_day
# Out:
#  * redshift+redshift_connector://ro_user:***@mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# [(15, 10),
#  (16, 9),
#  (10, 10),
#  (7, 10),
#  (18, 9),
#  (22, 11),
#  (9, 10),
#  (19, 9),
#  (5, 9),
#  (4, 10),
#  (2, 9),
#  (23, 10),
#  (14, 10),
#  (17, 9),
#  (20, 9),
#  (13, 10),
#  (6, 10),
#  (12, 10),
#  (21, 10),
#  (11, 10),
#  (8, 10),
#  (0, 10),
#  (1, 9),
#  (3, 10)]

# %% [markdown]
# ## Find the most commonly ordered products

# %%
# %%sql
# select op.product_id, p.product_name, count(op.product_id) as product_count
# from order_products op
# inner join products p on op.product_id = p.product_id
# group by op.product_id, p.product_name
# order by product_count desc
# limit 100
# Out:
#  * redshift+redshift_connector://ro_user:***@mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# [(24852, 'Banana', 472565),
#  (13176, 'Bag of Organic Bananas', 379450),
#  (21137, 'Organic Strawberries', 264683),
#  (21903, 'Organic Baby Spinach', 241921),
#  (47209, 'Organic Hass Avocado', 213584),
#  (47766, 'Organic Avocado', 176815),
#  (47626, 'Large Lemon', 152657),
#  (16797, 'Strawberries', 142951),
#  (26209, 'Limes', 140627),
#  (27845, 'Organic Whole Milk', 137905),
#  (27966, 'Organic Raspberries', 137057),
#  (22935, 'Organic Yellow Onion', 113426),
#  (24964, 'Organic Garlic', 109778),
#  (45007, 'Organic Zucchini', 104823),
#  (39275, 'Organic Blueberries', 100060),
#  (49683, 'Cucumber Kirby', 97315),
#  (28204, 'Organic Fuji Apple', 89632),
#  (5876, 'Organic Lemon', 87746),
#  (8277, 'Apple Honeycrisp Organic', 85020),
#  (40706, 'Organic Grape Tomatoes', 84255),
#  (4920, 'Seedless Red Grapes', 82689),
#  (30391, 'Organic Cucumber', 80392),
#  (45066, 'Honeycrisp Apple', 79769),
#  (42265, 'Organic Baby Carrots', 76896),
#  (49235, 'Organic Half & Half', 76360),
#  (44632, 'Sparkling Water Grapefruit', 75886),
#  (19057, 'Organic Large Extra Fancy Fuji Apple', 75165),
#  (4605, 'Yellow Onions', 73167),
#  (37646, 'Organic Gala Apples', 72846),
#  (21616, 'Organic Baby Arugula', 72829),
#  (17794, 'Carrots', 72736),
#  (27104, 'Fresh Cauliflower', 71584),
#  (30489, 'Original Hummus', 71314),
#  (31717, 'Organic Cilantro', 69524),
#  (27086, 'Half & Half', 69217),
#  (44359, 'Organic Small Bunch Celery', 68091),
#  (28985, 'Michigan Organic Kale', 67449),
#  (46979, 'Asparagus', 67283),
#  (8518, 'Organic Red Onion', 66986),
#  (41950, 'Organic Tomato Cluster', 64289),
#  (26604, 'Organic Blackberries', 61746),
#  (5077, '100% Whole Wheat Bread', 60816),
#  (34126, 'Organic Italian Parsley Bunch', 60621),
#  (22035, 'Organic Whole String Cheese', 59676),
#  (39877, 'Organic Granny Smith Apple', 58779),
#  (35951, 'Organic Unsweetened Almond Milk', 57895),
#  (43352, 'Raspberries', 57640),
#  (10749, 'Organic Red Bell Pepper', 57485),
#  (19660, 'Spring Water', 56087),
#  (9076, 'Blueberries', 55946),
#  (21938, 'Green Bell Pepper', 55484),
#  (43961, 'Organic Peeled Whole Baby Carrots', 55371),
#  (24184, 'Red Peppers', 55280),
#  (34969, 'Red Vine Tomato', 54409),
#  (46667, 'Organic Ginger Root', 52087),
#  (48679, 'Organic Garnet Sweet Potato (Yam)', 51939),
#  (25890, 'Boneless Skinless Chicken Breasts', 50281),
#  (31506, 'Extra Virgin Olive Oil', 50255),
#  (12341, 'Hass Avocados', 50221),
#  (39928, 'Organic Kiwi', 50141),
#  (24838, 'Unsweetened Almondmilk', 49569),
#  (5450, 'Small Hass Avocado', 49021),
#  (22825, "Organic D'Anjou Pears", 48915),
#  (5785, 'Organic Reduced Fat 2% Milk', 47839),
#  (35221, 'Lime Sparkling Water', 46546),
#  (28842, 'Bunched Cilantro', 45530),
#  (33731, 'Grated Parmesan', 45238),
#  (27521, 'Organic Lacinato (Dinosaur) Kale', 43067),
#  (44142, 'Red Onion', 43009),
#  (33198, 'Sparkling Natural Mineral Water', 42934),
#  (8174, 'Organic Navel Orange', 42721),
#  (20114, 'Jalapeno Peppers', 42561),
#  (8424, 'Broccoli Crown', 42044),
#  (27344, 'Uncured Genoa Salami', 41473),
#  (11520, 'Large Alfresco Eggs', 40376),
#  (29487, 'Roma Tomato', 40212),
#  (18465, 'Organic Grade A Free Range Large Brown Eggs', 40045),
#  (28199, 'Clementines, Bag', 39825),
#  (15290, 'Orange Bell Pepper', 39188),
#  (46906, 'Grape White/Green Seedless', 38971),
#  (9839, 'Organic Broccoli', 38720),
#  (27156, 'Organic Black Beans', 38001),
#  (3957, '100% Raw Coconut Water', 37973),
#  (43122, 'Organic Bartlett Pear', 37706),
#  (23909, '2% Reduced Fat Milk', 37091),
#  (34358, 'Garlic', 36617),
#  (4799, 'Shredded Parmesan', 36365),
#  (9387, 'Granny Smith Apples', 36187),
#  (16759, 'Organic Carrot Bunch', 35820),
#  (196, 'Soda', 35791),
#  (42736, 'Unsalted Butter', 35667),
#  (38689, 'Organic Reduced Fat Milk', 35663),
#  (4210, 'Whole Milk', 35633),
#  (41787, 'Bartlett Pears', 35413),
#  (41220, 'Organic Romaine Lettuce', 34874),
#  (47144, 'Unsweetened Original Almond Breeze Almond Milk', 34583),
#  (7781, 'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese', 34209),
#  (33000, 'Pure Irish Butter', 33908),
#  (20995, 'Organic Broccoli Florets', 32887),
#  (21709, 'Sparkling Lemon Water', 32788)]

# %% [markdown]
# ## Find the most commonly ordered products in the evening hours (18-23)

# %%
# %%sql
#
# select op.product_id, p.product_name, count(op.product_id) as product_count
# from orders o
# inner join order_products op on o.order_id = op.order_id
# inner join products p on op.product_id = p.product_id
# where o.order_hour_of_day >= 18 and o.order_hour_of_day <=23
# group by op.product_id, p.product_name
# order by product_count desc
# limit 100
# Out:
#  * redshift+redshift_connector://ro_user:***@mbai417-redshift.cuvtmrb8eogw.us-west-2.redshift.amazonaws.com:5439/dev
# Done.
# [(24852, 'Banana', 83870),
#  (13176, 'Bag of Organic Bananas', 67351),
#  (21137, 'Organic Strawberries', 49211),
#  (21903, 'Organic Baby Spinach', 43830),
#  (47209, 'Organic Hass Avocado', 38181),
#  (47766, 'Organic Avocado', 31455),
#  (27845, 'Organic Whole Milk', 25697),
#  (47626, 'Large Lemon', 25207),
#  (16797, 'Strawberries', 25145),
#  (27966, 'Organic Raspberries', 24913),
#  (26209, 'Limes', 23591),
#  (39275, 'Organic Blueberries', 19128),
#  (45007, 'Organic Zucchini', 18683),
#  (22935, 'Organic Yellow Onion', 18475),
#  (24964, 'Organic Garlic', 18314),
#  (49683, 'Cucumber Kirby', 17850),
#  (40706, 'Organic Grape Tomatoes', 15545),
#  (5876, 'Organic Lemon', 15456),
#  (28204, 'Organic Fuji Apple', 15002),
#  (4920, 'Seedless Red Grapes', 14908),
#  (30391, 'Organic Cucumber', 14493),
#  (8277, 'Apple Honeycrisp Organic', 14428),
#  (45066, 'Honeycrisp Apple', 13667),
#  (42265, 'Organic Baby Carrots', 13664),
#  (17794, 'Carrots', 13317),
#  (37646, 'Organic Gala Apples', 13148),
#  (19057, 'Organic Large Extra Fancy Fuji Apple', 13109),
#  (27104, 'Fresh Cauliflower', 12805),
#  (30489, 'Original Hummus', 12783),
#  (21616, 'Organic Baby Arugula', 12668),
#  (4605, 'Yellow Onions', 12349),
#  (28985, 'Michigan Organic Kale', 12321),
#  (31717, 'Organic Cilantro', 12005),
#  (41950, 'Organic Tomato Cluster', 11836),
#  (8518, 'Organic Red Onion', 11684),
#  (26604, 'Organic Blackberries', 11481),
#  (46979, 'Asparagus', 11464),
#  (44359, 'Organic Small Bunch Celery', 11310),
#  (19660, 'Spring Water', 11188),
#  (44632, 'Sparkling Water Grapefruit', 11182),
#  (35951, 'Organic Unsweetened Almond Milk', 10656),
#  (10749, 'Organic Red Bell Pepper', 10636),
#  (5077, '100% Whole Wheat Bread', 10460),
#  (39877, 'Organic Granny Smith Apple', 10377),
#  (22035, 'Organic Whole String Cheese', 10264),
#  (9076, 'Blueberries', 10239),
#  (43961, 'Organic Peeled Whole Baby Carrots', 10064),
#  (21938, 'Green Bell Pepper', 10050),
#  (34126, 'Organic Italian Parsley Bunch', 10042),
#  (49235, 'Organic Half & Half', 10038),
#  (39928, 'Organic Kiwi', 10028),
#  (27086, 'Half & Half', 9936),
#  (43352, 'Raspberries', 9799),
#  (24184, 'Red Peppers', 9579),
#  (34969, 'Red Vine Tomato', 9554),
#  (46667, 'Organic Ginger Root', 9416),
#  (48679, 'Organic Garnet Sweet Potato (Yam)', 8988),
#  (22825, "Organic D'Anjou Pears", 8972),
#  (31506, 'Extra Virgin Olive Oil', 8886),
#  (25890, 'Boneless Skinless Chicken Breasts', 8778),
#  (12341, 'Hass Avocados', 8677),
#  (5450, 'Small Hass Avocado', 8640),
#  (24838, 'Unsweetened Almondmilk', 8307),
#  (33731, 'Grated Parmesan', 7891),
#  (8174, 'Organic Navel Orange', 7828),
#  (27521, 'Organic Lacinato (Dinosaur) Kale', 7686),
#  (28842, 'Bunched Cilantro', 7627),
#  (33198, 'Sparkling Natural Mineral Water', 7548),
#  (29487, 'Roma Tomato', 7467),
#  (46906, 'Grape White/Green Seedless', 7463),
#  (8424, 'Broccoli Crown', 7370),
#  (5785, 'Organic Reduced Fat 2% Milk', 7367),
#  (3957, '100% Raw Coconut Water', 7204),
#  (44142, 'Red Onion', 7177),
#  (43122, 'Organic Bartlett Pear', 7120),
#  (18465, 'Organic Grade A Free Range Large Brown Eggs', 7100),
#  (27344, 'Uncured Genoa Salami', 7012),
#  (20114, 'Jalapeno Peppers', 6892),
#  (28199, 'Clementines, Bag', 6814),
#  (15290, 'Orange Bell Pepper', 6803),
#  (9839, 'Organic Broccoli', 6799),
#  (34358, 'Garlic', 6779),
#  (35221, 'Lime Sparkling Water', 6756),
#  (38689, 'Organic Reduced Fat Milk', 6754),
#  (11520, 'Large Alfresco Eggs', 6702),
#  (27156, 'Organic Black Beans', 6529),
#  (4210, 'Whole Milk', 6459),
#  (42736, 'Unsalted Butter', 6423),
#  (23909, '2% Reduced Fat Milk', 6386),
#  (4799, 'Shredded Parmesan', 6267),
#  (16759, 'Organic Carrot Bunch', 6141),
#  (41220, 'Organic Romaine Lettuce', 6096),
#  (41787, 'Bartlett Pears', 6048),
#  (5479, 'Italian Sparkling Mineral Water', 6022),
#  (20995, 'Organic Broccoli Florets', 5983),
#  (7781, 'Organic Sticks Low Moisture Part Skim Mozzarella String Cheese', 5930),
#  (26369, 'Organic Roma Tomato', 5863),
#  (47144, 'Unsweetened Original Almond Breeze Almond Milk', 5839),
#  (24489, 'Organic Whole Strawberries', 5819),
#  (40604, 'Feta Cheese Crumbles', 5769)]

# %% [markdown]
# ## Calculate products that have the highest percentage of sales in the evening hours

# %%
# %%sql

# %% [markdown]
# # Final analysis
# In the markdown cell below summarize your findings.  Which products have the highest proportion of sales in evening hours?  Should the merchandising team focus on email or on-site featuring to drive incremental orders.  What additional data would you collect to evaluate the opportunity? Please limit your response to 250 words (+/-)

# %% [markdown]
# Summary here
